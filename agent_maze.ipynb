# %% [markdown]
# # Agent Maze Test
#
# In this notebook, we will use a procedural maze generator to create a maze and then use an agent to navigate the maze.
#
# Using this, we can test the performance of an agent navigating the maze, and compare various LLM models tracking
# - time spent
# - number of tool calls
# - if they ever find the treasure (we will set some maximum number of steps to avoid infinite loops)

# %%
# %pip install -U llama-index-llms-openai

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-..."

# %% [markdown]
# ## Maze Generation
#
# We've vibe-coded a procedural maze generator in `procedural_maze_generator.py`. Hopefully it generates a valid maze! (It does)
#
# Let's start by generating three mazes with different difficulties.

# %%
import os
import shutil
from procedural_maze_generator import ProceduralMazeGenerator, MazeConfig, DifficultyLevel

maze_configs = [
    MazeConfig(
        depth=2,
        difficulty=DifficultyLevel.EASY,
        theme="fantasy",
    ),
    MazeConfig(
        depth=3,
        difficulty=DifficultyLevel.MEDIUM,
        theme="sci-fi",
    ),
    MazeConfig(
        depth=5,
        difficulty=DifficultyLevel.HARD,
        theme="mystery",
        enable_math=True,
        enable_coordinates=True,
        enable_riddles=True,
    )
]

maze_paths = [
    f"./mazes/easy_maze",
    f"./mazes/medium_maze",
    f"./mazes/hard_maze",
]

# Clear out the mazes directory
if os.path.exists("./mazes"):
    shutil.rmtree("./mazes")
    os.makedirs("./mazes", exist_ok=True)

# Generate the mazes
generators = [ProceduralMazeGenerator(maze_config) for maze_config in maze_configs]
for i, maze_path in enumerate(maze_paths):
    generators[i].generate_maze(maze_path)

    stats = generators[i].get_maze_stats()
    print(f"Stats: {stats['total_nodes']} nodes, {stats['total_files']} files")
    print(f"Solution: {' → '.join(stats['solution_path'])}")
    print('-' * 50)
# Out:
# 🎲 Generating procedural maze (depth=2, theme=fantasy)
# ✅ Generated maze with 9 nodes
# 🎯 Treasure path: entrance → mystic_orb_chamber
# Stats: 9 nodes, 4 files
# Solution: entrance → mystic_orb_chamber
# --------------------------------------------------
# 🎲 Generating procedural maze (depth=3, theme=sci-fi)
# ✅ Generated maze with 24 nodes
# 🎯 Treasure path: entrance → station → quantum_core_chamber
# Stats: 24 nodes, 9 files
# Solution: entrance → station → quantum_core_chamber
# --------------------------------------------------
# 🎲 Generating procedural maze (depth=5, theme=mystery)
# ✅ Generated maze with 204 nodes
# 🎯 Treasure path: entrance → vault → office → gallery → missing_will_chamber
# Stats: 204 nodes, 74 files
# Solution: entrance → vault → office → gallery → missing_will_chamber
# --------------------------------------------------

# %% [markdown]
# ## Constructing our Agent
#
# To navigate the maze, we will provide the agent with a set of simple tools and instructions.
#
# Obviously, some tools could find the solution instantly, but we want to test the performance of an agent navigating the maze, so we will limit how useful the tools are.

# %% [markdown]
# ### Tools
#
# First, we can construct a simple toolkit for the agent to use. This will contain the tools that the agent can use to navigate the maze and solve the puzzles.

# %%
import asyncio
import os

class AgentMazeToolkit:

    def __init__(self, generator: ProceduralMazeGenerator, maze_path: str):
        self.current_generator = generator
        self.maze_path = maze_path


    async def list_directory(self, path: str) -> list[str]:
        """List the contents of a directory."""
        # Check if the path is within the maze directory
        if not path.startswith(self.maze_path):
            return ["❌ Error: Path is outside of maze directory"]
        
        # Check if the path is a file
        if os.path.isfile(path):
            return ["❌ Error: Path is a file"]
        
        def _list_directory():
            paths = os.listdir(path)

            # Add markers to distinguish between directories and files
            for idx, p in enumerate(paths):
                if os.path.isdir(os.path.join(path, p)):
                    paths[idx] = "(dir) " + p
                else:
                    paths[idx] = "(file) " + p
                    
            return paths
        
        return await asyncio.to_thread(_list_directory)

    async def read_file(self, path: str) -> str:
        """Read the contents of a file."""
        # Check if the path is within the maze directory
        if not path.startswith(self.maze_path):
            return ["❌ Error: Path is outside of maze directory"]
        
        # Check if the path is a directory
        if os.path.isdir(path):
            return ["❌ Error: Path is a directory"]
        
        def _read():
            with open(path, "r") as f:
                return f.read()
            
        return await asyncio.to_thread(_read)

    async def check_coordinate(self, x: str, y: str) -> str:
        """Check if coordinates lead to the treasure location."""
     
        # Get the actual solution path from the generator
        solution_path = self.current_generator.get_solution_path()
        target_path = f"{x}/{y}"
        
        # Check if this matches any part of the solution
        solution_parts = "/".join(solution_path[1:])  # Skip entrance
        if target_path in solution_parts or (x in solution_parts and y in solution_parts):
            result = f"🎯 Coordinates ({x}, {y}) are CORRECT! This leads toward the treasure!"
        else:
            result = f"❌ Coordinates ({x}, {y}) do not lead to treasure. Keep searching!"
        
        return result

# %% [markdown]
# ### Prompts
#
# We need to give a prompt to the agent for both
# - the system prompt
# - the initial task prompt
#
# The hope is that the agent will run the task and won't stop until it has found the treasure.

# %%
def get_system_prompt(maze_path: str, theme: str, difficulty: str, depth: int) -> str:
    return f"""You are competing in a procedural maze tournament!

This is a {difficulty} difficulty {theme} themed maze with {depth} levels.

The maze is represented as a directory structure starting at {maze_path}.

Your goal: Find the treasure hidden in this randomly generated maze.

Available tools:
- list_directory(path): Explore directories  
- read_file(file_path): Read file contents for clues
- check_coordinate(x, y): Test coordinate combinations  

Strategy for {theme} theme:
- Look for {theme}-themed location names and objects
- Clues will reference the theme's vocabulary
- The treasure will have a {theme}-appropriate name

Show your systematic reasoning skills! Remember, the maze path starts at {maze_path}.
"""

def get_task_prompt(maze_path: str, theme: str, difficulty: str) -> str:
    return f"""Navigate this procedural {theme} maze at {maze_path} to find the hidden treasure!

This maze was randomly generated with {difficulty} difficulty. Use your tools strategically to:
1. Explore the maze structure systematically
2. Read files for clues and puzzle solutions
3. Decode any encrypted messages you find
4. Follow logical progression of clues to the treasure

The maze contains both helpful clues and red herrings."""

# %% [markdown]
# ## Testing the Agents
#
# Using everything we have so far, we can test the agents on the mazes.
#
# We will use the following metrics for each LLM/Maze combination:
# - Tool calls
# - Time spent
# - Success
#
# Using the `FunctionAgent` class from `llama_index`, we can create an agent that can use the tools we have defined.
#
# As the agent runs, we can track the events from the stream to keep track of the tool calls and time spent.
#
# Once the agent finishes, we have an automated check to see if the agent actually finished or bailed early.

# %%
import time
from llama_index.core.agent import FunctionAgent, ToolCallResult
from llama_index.core.workflow import Context
from llama_index.llms.openai import OpenAIResponses

llms_to_test = ["gpt-5-2025-08-07", "gpt-5-mini-2025-08-07", "gpt-5-nano-2025-08-07"]
test_results = {llm_name: {} for llm_name in llms_to_test}

for llm_name in llms_to_test:
    for (maze_path, generator) in zip(maze_paths, generators):
        print("=" * 70)
        print(f"Testing {llm_name} on {maze_path}")
        print("=" * 70)
        
        # Note: OpenAI was quite buggy when testing this, so we've upped the max retries and timeout
        llm = OpenAIResponses(model=llm_name, max_retries=10, timeout=360)
        kit = AgentMazeToolkit(generator, maze_path)
        test_results[llm_name][maze_path] = {
            "tool_calls": 0,
            "time_spent": 0,
            "success": False,
        }

        agent = FunctionAgent(
            llm=llm,
            tools=[
                kit.list_directory,
                kit.read_file,
                kit.check_coordinate,
            ],
            system_prompt=get_system_prompt(maze_path, generator.config.theme, generator.config.difficulty.value, generator.config.depth)
        )
        ctx = Context(agent)

        task = get_task_prompt(maze_path, generator.config.theme, generator.config.difficulty.value)
        
        is_done = False
        tool_results = []
        while not is_done:
            start_time = time.time()

            try:
                handler = agent.run(task, ctx=ctx, max_iterations=100)
                async for event in handler.stream_events():
                    if isinstance(event, ToolCallResult):
                        test_results[llm_name][maze_path]["tool_calls"] += 1
                        tool_results.append(event.tool_output)
                        print(f"Calling {event.tool_name}({event.tool_kwargs}) -> {event.tool_output}")
                
                response = await handler
            except Exception as e:
                if "Max iterations" in str(e):
                    print("Max iterations reached! Agent has failed! Halting search to avoid infinite loops...")
                    break
                else:
                    raise e

            # Confirm if actually done by checking the tool results for the treasure
            possible_treasure_names = [name.lower() for name in generator.themes[generator.config.theme]["treasures"]]
            for tool_result in tool_results:
                for treasure_name in possible_treasure_names:
                    if treasure_name in str(tool_result).lower():
                        print(f"Found treasure! {treasure_name}")
                        is_done = True
                        break
                    
                if is_done:
                    break

        test_results[llm_name][maze_path]["time_spent"] = time.time() - start_time
        test_results[llm_name][maze_path]["success"] = is_done

print(test_results)
# Out:
# ======================================================================
# Testing gpt-5-2025-08-07 on ./mazes/easy_maze
# ======================================================================
# Calling list_directory({'path': './mazes/easy_maze'}) -> ['(dir) scroll', '(dir) mystic_orb_chamber', '(file) rules.txt', '(dir) ruins', '(file) welcome.txt', '(dir) altar']
# Calling read_file({'path': './mazes/easy_maze/welcome.txt'}) -> Welcome, brave explorer! The GOLDEN_IDOL awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/easy_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/scroll'}) -> ['(dir) gem']
# Calling list_directory({'path': './mazes/easy_maze/ruins'}) -> ['(dir) throne']
# Calling read_file({'path': './mazes/easy_maze/altar/GOLDEN_IDOL.txt'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/altar/GOLDEN_IDOL.txt'
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/scroll'}) -> ['(dir) gem']
# Calling list_directory({'path': './mazes/easy_maze/ruins'}) -> ['(dir) throne']
# Calling list_directory({'path': './mazes/easy_maze/scroll'}) -> ['(dir) gem']
# Calling list_directory({'path': './mazes/easy_maze/ruins'}) -> ['(dir) throne']
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/altar/gem'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/altar/gem'
# Calling list_directory({'path': './mazes/easy_maze/scroll/throne'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/scroll/throne'
# Calling list_directory({'path': './mazes/easy_maze/ruins/cavern'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/ruins/cavern'
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber/cavern'}) ->
# Calling read_file({'path': './mazes/easy_maze/ruins/misleading_clue_6.txt'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/ruins/misleading_clue_6.txt'
# Calling read_file({'path': './mazes/easy_maze/mystic_orb_chamber/GOLDEN_IDOL.txt'}) -> 🏆 CONGRATULATIONS! You found the CRYSTAL_CROWN! 🏆
#
# The legendary treasure has been claimed by a worthy explorer.
# This crystal crown grants great power to its finder.
#
# You have successfully navigated the procedural maze and proven your intelligence!
#
# Maze Statistics:
# - Depth: 2 levels
# - Theme: fantasy
# - Difficulty: easy
# - Branching Factor: 3
#
# Found treasure! mystic_orb
# Found treasure! golden_idol
# Found treasure! golden_idol
# Found treasure! golden_idol
# Found treasure! golden_idol
# Found treasure! golden_idol
# Found treasure! crystal_crown
# ======================================================================
# Testing gpt-5-2025-08-07 on ./mazes/medium_maze
# ======================================================================
# Calling list_directory({'path': './mazes/medium_maze'}) -> ['(dir) bay', '(file) rules.txt', '(dir) station', '(file) welcome.txt']
# Calling read_file({'path': './mazes/medium_maze/welcome.txt'}) -> Welcome, brave explorer! The NEURAL_MATRIX awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/medium_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/medium_maze/bay'}) -> ['(dir) lab', '(dir) quantum_core_chamber', '(dir) data', '(dir) console']
# Calling list_directory({'path': './mazes/medium_maze/station'}) -> ['(dir) bridge', '(dir) crystal', '(dir) quantum_core_chamber', '(dir) engine']
# Calling list_directory({'path': './mazes/medium_maze/bay/lab'}) -> ['(dir) chamber', '(dir) vault']
# Calling list_directory({'path': './mazes/medium_maze/bay/quantum_core_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) vault']
# Calling list_directory({'path': './mazes/medium_maze/bay/data'}) -> ['(dir) chamber', '(dir) station', '(dir) scanner']
# Calling list_directory({'path': './mazes/medium_maze/bay/console'}) -> ['(dir) data']
# Calling read_file({'path': './mazes/medium_maze/bay/quantum_core_chamber/GOLDEN_IDOL.txt'}) -> 🏆 CONGRATULATIONS! You found the FUSION_CELL! 🏆
#
# The legendary treasure has been claimed by a worthy explorer.
# This fusion cell grants great power to its finder.
#
# You have successfully navigated the procedural maze and proven your intelligence!
#
# Maze Statistics:
# - Depth: 3 levels
# - Theme: sci-fi
# - Difficulty: medium
# - Branching Factor: 3
#
# Found treasure! neural_matrix
# Found treasure! quantum_core
# Found treasure! quantum_core
# Found treasure! fusion_cell
# ======================================================================
# Testing gpt-5-2025-08-07 on ./mazes/hard_maze
# ======================================================================
# Calling list_directory({'path': './mazes/hard_maze'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/welcome.txt'}) -> Welcome, brave explorer! The HIDDEN_TRUTH awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/hard_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/study/misleading_clue_2.txt'}) -> This treasure is just an illusion.
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/vault'}) -> ['(dir) study', '(dir) evidence', '(dir) office', '(dir) letter', '(file) clue_riddle.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/clue_riddle.txt'}) -> Three letters start my name, OFF. Find where I remain.
# Calling list_directory({'path': './mazes/hard_maze/study/office'}) -> ['(file) clue_pattern.txt', '(dir) gallery', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/study/letter'}) -> ['(dir) safe', '(dir) study', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/study/painting'}) -> ['(dir) gallery', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/safe/salon'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/study'}) -> ['(dir) safe', '(dir) gallery', '(dir) key', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence'}) -> ['(dir) clue', '(dir) gallery', '(dir) diary', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) safe', '(dir) salon', '(dir) office', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/vault/letter'}) -> ['(dir) safe', '(dir) gallery', '(dir) key', '(file) misleading_clue_6.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling read_file({'path': './mazes/hard_maze/key/clue_pattern.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/clue_pattern.txt'
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/vault'}) -> ['(dir) study', '(dir) evidence', '(dir) office', '(dir) letter', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) safe', '(dir) salon', '(dir) office', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/safe/salon'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/office'}) -> ['(file) clue_pattern.txt', '(dir) gallery', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/study/office/clue_pattern.txt'}) -> The pattern spells: G A L L E R Y
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery'}) -> ['(file) clue_coordinates.txt', '(dir) gallery', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/study/office/gallery/clue_coordinates.txt'}) -> Treasure lies where gallery meets missing_will_chamber
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber'}) -> ['(file) clue_pattern.txt', '(dir) gallery', '(dir) library', '(dir) key']
# Calling read_file({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/clue_pattern.txt'}) -> Follow the sequence to: GALLERY
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/gallery'}) -> ['(file) misleading_clue_4.txt']
# Calling read_file({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/gallery/misleading_clue_4.txt'}) -> This path leads nowhere useful.
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/library'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office/study'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office/diary'}) -> ['(dir) clue', '(dir) office', '(dir) missing_will_chamber', "(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study'}) -> ['(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery'}) -> ['(dir) clue', '(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery'}) -> ['(dir) salon', '(dir) evidence', '(dir) document', '(dir) missing_will_chamber', '(file) clue_math.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': "./mazes/hard_maze/key/fool's_gold.txt"}) -> [Errno 2] No such file or directory: "./mazes/hard_maze/key/fool's_gold.txt"
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) safe', '(dir) salon', '(dir) office', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/key/salon'}) -> ['(dir) safe', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/key/salon/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/salon/gallery'}) -> ['(file) clue_pattern.txt', '(dir) gallery', '(dir) letter', '(dir) missing_will_chamber', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/key/salon/gallery/clue_pattern.txt'}) -> The pattern spells: M I S S I N G _ W I L L _ C H A M B E R
# Calling list_directory({'path': './mazes/hard_maze/key/salon/gallery/missing_will_chamber'}) -> ['(dir) salon', '(dir) evidence', '(dir) basement']
# Calling list_directory({'path': './mazes/hard_maze/key/salon/gallery/missing_will_chamber/evidence'}) -> ['(file) misleading_clue_9.txt']
# Calling read_file({'path': './mazes/hard_maze/key/salon/gallery/missing_will_chamber/evidence/misleading_clue_9.txt'}) -> This path leads nowhere useful.
# Calling list_directory({'path': './mazes/hard_maze/key/salon/gallery/missing_will_chamber/basement'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/salon/gallery/missing_will_chamber/salon'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery'}) -> ['(dir) clue', '(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (diary, missing_will_chamber)
# Calling check_coordinate({'x': 'diary', 'y': 'missing_will_chamber'}) -> ❌ Coordinates (diary, missing_will_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/study/letter'}) -> ['(dir) safe', '(dir) study', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/vault/letter'}) -> ['(dir) safe', '(dir) gallery', '(dir) key', '(file) misleading_clue_6.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/letter/misleading_clue_6.txt'}) -> This treasure is just an illusion.
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence'}) -> ['(dir) clue', '(dir) gallery', '(dir) diary', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence/clue'}) -> ['(file) misleading_clue_9.txt', '(file) empty_chest.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/evidence/clue/empty_chest.txt'}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence/diary'}) -> ['(dir) clue', '(dir) study', '(dir) salon', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence/diary/missing_will_chamber'}) -> ['(dir) library', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence/diary/missing_will_chamber/library'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence/diary/missing_will_chamber/key'}) -> ['(file) empty_chest.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/evidence/diary/missing_will_chamber/key/empty_chest.txt'}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/study/office/vault'}) -> ['(file) misleading_clue_7.txt']
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery'}) -> ['(file) clue_coordinates.txt', '(dir) gallery', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/key/office/misleading_clue_7.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/misleading_clue_7.txt'
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/missing_will_chamber'
# Calling read_file({'path': './mazes/hard_maze/vault/office/clue_coordinates.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/clue_coordinates.txt'
# Calling read_file({'path': './mazes/hard_maze/safe/office/clue_coordinates.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/safe/office/clue_coordinates.txt'
# Calling list_directory({'path': './mazes/hard_maze/study/office/vault'}) -> ['(file) misleading_clue_7.txt']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/safe'}) -> ['(dir) diary', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office/diary'}) -> ['(dir) clue', '(dir) office', '(dir) missing_will_chamber', "(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery'}) -> ['(dir) salon', '(dir) evidence', '(dir) document', '(dir) missing_will_chamber', '(file) clue_math.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study'}) -> ['(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/attic'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': "./mazes/hard_maze/key/attic/fool's_gold.txt"}) -> [Errno 2] No such file or directory: "./mazes/hard_maze/key/attic/fool's_gold.txt"
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery'}) -> ['(dir) salon', '(dir) evidence', '(dir) document', '(dir) missing_will_chamber', '(file) clue_math.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/office/gallery/clue_math.txt'}) -> Solve: 26 ÷ 2 = 13 = M. First letter of your destination.
# Calling check_coordinate({'x': 'gallery', 'y': 'missing_will_chamber'}) -> 🎯 Coordinates (gallery, missing_will_chamber) are CORRECT! This leads toward the treasure!
# Calling read_file({'path': './mazes/hard_maze/key/office/misleading_clue_7.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/misleading_clue_7.txt'
# Calling list_directory({'path': './mazes/hard_maze/safe/office/diary'}) -> ['(dir) clue', '(dir) office', '(dir) missing_will_chamber', "(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber'}) -> ['(dir) safe', '(dir) attic', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber/attic'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber/diary'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/missing_will_chamber'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/document'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/document'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/letter/gallery'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/letter/gallery'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/document/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/document/missing_will_chamber'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/letter/gallery/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/letter/gallery/missing_will_chamber'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/clue_logic.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/key/clue_logic.txt'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/painting'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/key/painting'
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber'}) -> ['(dir) safe', '(dir) attic', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/attic'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery'}) -> ['(dir) salon', '(dir) evidence', '(dir) document', '(dir) missing_will_chamber', '(file) clue_math.txt']
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) safe', '(dir) salon', '(dir) office', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery'}) -> ['(file) clue_coordinates.txt', '(dir) gallery', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/key/salon/gallery/missing_will_chamber'}) -> ['(dir) salon', '(dir) evidence', '(dir) basement']
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) safe', '(dir) salon', '(dir) office', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/vault'}) -> ['(dir) study', '(dir) evidence', '(dir) office', '(dir) letter', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/letter'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/letter'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/missing_will_chamber'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/letter'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/gallery'}) -> ['(dir) document']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/evidence'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/document'}) -> ['(dir) gallery', '(dir) letter', '(dir) key']
# Calling read_file({'path': './mazes/hard_maze/vault/office/gallery/clue_math.txt'}) -> Solve: 26 ÷ 2 = 13 = M. First letter of your destination.
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/document'}) -> ['(dir) gallery', '(dir) letter', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/document/gallery'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/document/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/document/letter'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/painting'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/safe/office/gallery/painting'
# Calling list_directory({'path': './mazes/hard_maze/study/office/vault'}) -> ['(file) misleading_clue_7.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study'}) -> ['(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/key/office/misleading_clue_7.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/misleading_clue_7.txt'
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/painting'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/clue_logic.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/key/clue_logic.txt'
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/key/office/clue_coordinates.txt'}) -> The coordinates are marked: X=office, Y=gallery
# Calling check_coordinate({'x': 'office', 'y': 'gallery'}) -> 🎯 Coordinates (office, gallery) are CORRECT! This leads toward the treasure!
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery'}) -> ['(dir) evidence', '(file) clue_pattern.txt', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/clue_pattern.txt'}) -> The pattern spells: M I S S I N G _ W I L L _ C H A M B E R
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber'}) -> ['(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/evidence'}) -> ['(dir) evidence']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/evidence'}) ->
# Calling check_coordinate({'x': 'office', 'y': 'missing_will_chamber'}) -> 🎯 Coordinates (office, missing_will_chamber) are CORRECT! This leads toward the treasure!
# Calling list_directory({'path': './mazes/hard_maze/vault/office/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/missing_will_chamber'
# Calling list_directory({'path': './mazes/hard_maze/key/office/missing_will_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/missing_will_chamber'
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/key/office/vault'}) -> ['(dir) office', '(file) misleading_clue_8.txt', '(dir) missing_will_chamber']
# Max iterations reached! Agent has failed! Halting search to avoid infinite loops...
# ======================================================================
# Testing gpt-5-mini-2025-08-07 on ./mazes/easy_maze
# ======================================================================
# Calling list_directory({'path': './mazes/easy_maze'}) -> ['(dir) scroll', '(dir) mystic_orb_chamber', '(file) rules.txt', '(dir) ruins', '(file) welcome.txt', '(dir) altar']
# Calling read_file({'path': './mazes/easy_maze/welcome.txt'}) -> Welcome, brave explorer! The GOLDEN_IDOL awaits those clever enough to solve the ancient puzzles.
# Calling list_directory({'path': './mazes/easy_maze/scroll'}) -> ['(dir) gem']
# Calling list_directory({'path': './mazes/easy_maze/scroll/gem'}) ->
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) cavern']
# Calling read_file({'path': './mazes/easy_maze/mystic_orb_chamber/GOLDEN_IDOL.txt'}) -> 🏆 CONGRATULATIONS! You found the CRYSTAL_CROWN! 🏆
#
# The legendary treasure has been claimed by a worthy explorer.
# This crystal crown grants great power to its finder.
#
# You have successfully navigated the procedural maze and proven your intelligence!
#
# Maze Statistics:
# - Depth: 2 levels
# - Theme: fantasy
# - Difficulty: easy
# - Branching Factor: 3
#
# Calling read_file({'path': './mazes/easy_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling read_file({'path': './mazes/easy_maze/altar/misleading_clue_6.txt'}) -> This path leads nowhere useful.
# Calling list_directory({'path': './mazes/easy_maze/altar/cavern'}) ->
# Calling list_directory({'path': './mazes/easy_maze/ruins'}) -> ['(dir) throne']
# Calling list_directory({'path': './mazes/easy_maze/ruins/throne'}) ->
# Found treasure! mystic_orb
# Found treasure! golden_idol
# Found treasure! golden_idol
# Found treasure! crystal_crown
# ======================================================================
# Testing gpt-5-mini-2025-08-07 on ./mazes/medium_maze
# ======================================================================
# Calling list_directory({'path': './mazes/medium_maze'}) -> ['(dir) bay', '(file) rules.txt', '(dir) station', '(file) welcome.txt']
# Calling read_file({'path': './mazes/medium_maze/welcome.txt'}) -> Welcome, brave explorer! The NEURAL_MATRIX awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/medium_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/medium_maze/bay'}) -> ['(dir) lab', '(dir) quantum_core_chamber', '(dir) data', '(dir) console']
# Calling list_directory({'path': './mazes/medium_maze/bay/lab'}) -> ['(dir) chamber', '(dir) vault']
# Calling list_directory({'path': './mazes/medium_maze/bay/lab/chamber'}) ->
# Calling list_directory({'path': './mazes/medium_maze/bay/lab/vault'}) -> ['(file) misleading_clue_6.txt', "(file) fool's_gold.txt"]
# Calling read_file({'path': './mazes/medium_maze/bay/lab/vault/misleading_clue_6.txt'}) -> This treasure is just an illusion.
# Calling read_file({'path': "./mazes/medium_maze/bay/lab/vault/fool's_gold.txt"}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/medium_maze/bay/quantum_core_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) vault']
# Calling read_file({'path': './mazes/medium_maze/bay/quantum_core_chamber/GOLDEN_IDOL.txt'}) -> 🏆 CONGRATULATIONS! You found the FUSION_CELL! 🏆
#
# The legendary treasure has been claimed by a worthy explorer.
# This fusion cell grants great power to its finder.
#
# You have successfully navigated the procedural maze and proven your intelligence!
#
# Maze Statistics:
# - Depth: 3 levels
# - Theme: sci-fi
# - Difficulty: medium
# - Branching Factor: 3
#
# Found treasure! neural_matrix
# Found treasure! quantum_core
# Found treasure! fusion_cell
# ======================================================================
# Testing gpt-5-mini-2025-08-07 on ./mazes/hard_maze
# ======================================================================
# Calling list_directory({'path': './mazes/hard_maze'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/welcome.txt'}) -> Welcome, brave explorer! The HIDDEN_TRUTH awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/hard_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/study/misleading_clue_2.txt'}) -> This treasure is just an illusion.
# Calling list_directory({'path': './mazes/hard_maze/study/office'}) -> ['(file) clue_pattern.txt', '(dir) gallery', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/study/office/clue_pattern.txt'}) -> The pattern spells: G A L L E R Y
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery'}) -> ['(file) clue_coordinates.txt', '(dir) gallery', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/study/office/gallery/clue_coordinates.txt'}) -> Treasure lies where gallery meets missing_will_chamber
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/gallery'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber'}) -> ['(file) clue_pattern.txt', '(dir) gallery', '(dir) library', '(dir) key']
# Calling read_file({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/clue_pattern.txt'}) -> Follow the sequence to: GALLERY
# Calling list_directory({'path': './mazes/hard_maze/study/painting'}) -> ['(dir) gallery', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/study/painting/gallery'}) -> ['(dir) safe', '(dir) key', '(dir) missing_will_chamber', '(file) clue_riddle.txt']
# Calling read_file({'path': './mazes/hard_maze/study/painting/gallery/clue_riddle.txt'}) -> Neither high nor low, but where missing_will_chamber grows.
# Calling list_directory({'path': './mazes/hard_maze/study/painting/painting'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/safe/salon'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/study'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery'}) -> ['(dir) clue', '(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/safe'}) -> ['(dir) diary', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (diary, missing_will_chamber)
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/safe/diary'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) safe', '(dir) salon', '(dir) office', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/key/safe'}) -> ['(dir) salon', '(dir) gallery', '(file) misleading_clue_5.txt', '(file) empty_chest.txt']
# Calling read_file({'path': './mazes/hard_maze/key/safe/misleading_clue_5.txt'}) -> This path leads nowhere useful.
# Calling read_file({'path': './mazes/hard_maze/key/safe/empty_chest.txt'}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/key/salon'}) -> ['(dir) safe', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/key/office/clue_coordinates.txt'}) -> The coordinates are marked: X=office, Y=gallery
# Calling list_directory({'path': './mazes/hard_maze/key/office/study'}) -> ['(dir) salon', '(dir) office', '(dir) missing_will_chamber', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery'}) -> ['(dir) evidence', '(file) clue_pattern.txt', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/clue_pattern.txt'}) -> The pattern spells: M I S S I N G _ W I L L _ C H A M B E R
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/evidence'}) -> ['(dir) evidence']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber'}) -> ['(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/key/office/library'}) -> ['(dir) evidence', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/office/vault'}) -> ['(dir) office', '(file) misleading_clue_8.txt', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/key/office/vault/misleading_clue_8.txt'}) -> A dead end disguised as progress.
# Calling list_directory({'path': './mazes/hard_maze/key/attic'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault'}) -> ['(dir) study', '(dir) evidence', '(dir) office', '(dir) letter', '(file) clue_riddle.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/clue_riddle.txt'}) -> Three letters start my name, OFF. Find where I remain.
# Calling list_directory({'path': './mazes/hard_maze/vault/study'}) -> ['(dir) safe', '(dir) gallery', '(dir) key', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/vault/study/gallery'}) -> ['(dir) study', '(dir) key', '(dir) missing_will_chamber', '(file) clue_math.txt', '(dir) diary']
# Calling read_file({'path': './mazes/hard_maze/vault/study/gallery/clue_math.txt'}) -> Solve: 26 ÷ 2 = 13 = M. First letter of your destination.
# Calling list_directory({'path': './mazes/hard_maze/vault/study/gallery/missing_will_chamber'}) -> ['(dir) study', '(file) clue_math.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/study/gallery/missing_will_chamber/clue_math.txt'}) -> Solve: 26 ÷ 2 = 13 = M. First letter of your destination.
# Calling check_coordinate({'x': 'office', 'y': 'missing_will_chamber'}) -> 🎯 Coordinates (office, missing_will_chamber) are CORRECT! This leads toward the treasure!
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/missing_will_chamber'}) -> ['(file) clue_pattern.txt', '(dir) attic']
# Calling read_file({'path': './mazes/hard_maze/vault/office/clue/missing_will_chamber/clue_pattern.txt'}) -> The symbols form: M-I-S-S-I-N-G-_-W-I-L-L-_-C-H-A-M-B-E-R
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/missing_will_chamber/attic'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence'}) -> ['(dir) clue', '(dir) gallery', '(dir) diary', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/vault/evidence/clue'}) -> ['(file) misleading_clue_9.txt', '(file) empty_chest.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/evidence/clue/misleading_clue_9.txt'}) -> A dead end disguised as progress.
# Calling read_file({'path': './mazes/hard_maze/vault/evidence/clue/empty_chest.txt'}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/painting'}) -> ['(dir) gallery', '(dir) document']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/painting/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study'}) -> ['(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study/safe'}) -> ['(dir) basement', '(dir) letter']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study/safe/basement'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/study/missing_will_chamber'}) -> ['(dir) salon', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery'}) -> ['(dir) salon', '(dir) evidence', '(dir) document', '(dir) missing_will_chamber', '(file) clue_math.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/office/gallery/clue_math.txt'}) -> Solve: 26 ÷ 2 = 13 = M. First letter of your destination.
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber/study'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/gallery/missing_will_chamber/study'
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/library'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/clue_logic.txt'}) -> The path of exclusion leads to MISSING_WILL_CHAMBER
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber'}) -> ['(dir) safe', '(dir) attic', '(dir) diary']
# Calling check_coordinate({'x': 'diary', 'y': 'missing_will_chamber'}) -> ❌ Coordinates (diary, missing_will_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/gallery'}) -> ['(file) misleading_clue_4.txt']
# Calling read_file({'path': './mazes/hard_maze/study/office/gallery/missing_will_chamber/gallery/misleading_clue_4.txt'}) -> This path leads nowhere useful.
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/gallery/missing_will_chamber/diary'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/letter'}) -> ['(dir) safe', '(dir) study', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/study/letter/safe'}) -> ['(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/study/letter/safe/missing_will_chamber'}) -> ['(dir) key', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/study/letter/safe/missing_will_chamber/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/letter/study'}) -> ['(dir) clue', '(file) misleading_clue_9.txt', '(dir) gallery', '(dir) document', '(file) broken_relic.txt', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/study/letter/study/misleading_clue_9.txt'}) -> This path leads nowhere useful.
# Calling read_file({'path': './mazes/hard_maze/study/letter/study/broken_relic.txt'}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/study/letter/study/gallery'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/letter'}) -> ['(dir) safe', '(dir) gallery', '(dir) key', '(file) misleading_clue_6.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/letter/misleading_clue_6.txt'}) -> This treasure is just an illusion.
# Calling list_directory({'path': './mazes/hard_maze/vault/letter/gallery'}) -> ['(dir) salon', '(dir) gallery', '(dir) document', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/vault/letter/gallery/missing_will_chamber'}) -> ['(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/vault/letter/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study/painting/gallery/missing_will_chamber'}) -> ['(dir) salon', '(file) clue_pattern.txt']
# Calling read_file({'path': './mazes/hard_maze/study/painting/gallery/missing_will_chamber/clue_pattern.txt'}) -> Follow the sequence to: GALLERY
# Calling list_directory({'path': './mazes/hard_maze/vault/letter/gallery/missing_will_chamber/office'}) -> ['(file) misleading_clue_6.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/painting'}) ->
# Calling list_directory({'path': './mazes/hard_maze/office'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/office'
# Max iterations reached! Agent has failed! Halting search to avoid infinite loops...
# ======================================================================
# Testing gpt-5-nano-2025-08-07 on ./mazes/easy_maze
# ======================================================================
# Calling list_directory({'path': './mazes/easy_maze'}) -> ['(dir) scroll', '(dir) mystic_orb_chamber', '(file) rules.txt', '(dir) ruins', '(file) welcome.txt', '(dir) altar']
# Calling list_directory({'path': './mazes/easy_maze/(dir) scroll'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/(dir) scroll'
# Calling list_directory({'path': './mazes/easy_maze/(dir) mystic_orb_chamber'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/(dir) mystic_orb_chamber'
# Calling read_file({'path': './mazes/easy_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling read_file({'path': './mazes/easy_maze/welcome.txt'}) -> Welcome, brave explorer! The GOLDEN_IDOL awaits those clever enough to solve the ancient puzzles.
# Calling list_directory({'path': './mazes/easy_maze/(dir) ruins'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/(dir) ruins'
# Calling list_directory({'path': './mazes/easy_maze/(dir) altar'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/(dir) altar'
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/ruins'}) -> ['(dir) throne']
# Calling list_directory({'path': './mazes/easy_maze/scroll'}) -> ['(dir) gem']
# Calling list_directory({'path': './mazes/easy_maze/scroll/mystic_orb_chamber'}) -> [Errno 2] No such file or directory: './mazes/easy_maze/scroll/mystic_orb_chamber'
# Calling read_file({'path': './mazes/easy_maze/scroll'}) -> ['❌ Error: Path is a directory']
# Calling list_directory({'path': './mazes/easy_maze/scroll'}) -> ['(dir) gem']
# Calling list_directory({'path': './mazes/easy_maze/scroll/gem'}) ->
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/altar/cavern'}) ->
# Calling read_file({'path': './mazes/easy_maze/altar/misleading_clue_6.txt'}) -> This path leads nowhere useful.
# Calling list_directory({'path': './mazes/easy_maze/altar'}) -> ['(file) misleading_clue_6.txt', '(dir) cavern']
# Calling read_file({'path': './mazes/easy_maze/ruins'}) -> ['❌ Error: Path is a directory']
# Calling list_directory({'path': './mazes/easy_maze/ruins'}) -> ['(dir) throne']
# Calling list_directory({'path': './mazes/easy_maze/ruins/throne'}) ->
# Calling list_directory({'path': './mazes/easy_maze/ruins/throne'}) ->
# Calling list_directory({'path': './mazes/easy_maze/ruins/throne'}) ->
# Calling list_directory({'path': './mazes/easy_maze/mystic_orb_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) cavern']
# ...
# Calling read_file({'path': './mazes/hard_maze/key/office/clue_riddle.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/clue_riddle.txt'
# Calling read_file({'path': './mazes/hard_maze/key/letter/misleading_clue_2.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/letter/misleading_clue_2.txt'
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/key/office/clue_coordinates.txt'}) -> The coordinates are marked: X=office, Y=gallery
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery'}) -> ['(dir) evidence', '(file) clue_pattern.txt', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/clue_pattern.txt'}) -> The pattern spells: M I S S I N G _ W I L L _ C H A M B E R
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber'}) -> ['(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber/key'}) ->
# Calling list_directory({'path': './mazes/hard_mamaze/vault'}) -> ['❌ Error: Path is outside of maze directory']
# Calling list_directory({'path': './mazes/hard_maze/key/letter'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/letter'
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery'}) -> ['(dir) evidence', '(file) clue_pattern.txt', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/office/library'}) -> ['(dir) evidence', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/office/evidence'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/evidence'
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber'}) -> ['(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/key/office/vault'}) -> ['(dir) office', '(file) misleading_clue_8.txt', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/key/office/study'}) -> ['(dir) salon', '(dir) office', '(dir) missing_will_chamber', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/vault'}) -> ['(dir) study', '(dir) evidence', '(dir) office', '(dir) letter', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/clue_pattern.txt'}) -> The pattern spells: M I S S I N G _ W I L L _ C H A M B E R
# Calling list_directory({'path': './mazes/hard_maze/key/office'}) -> ['(file) clue_coordinates.txt', '(dir) study', '(dir) gallery', '(dir) library', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/key/office/vault'}) -> ['❌ Error: Path is a directory']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery'}) -> ['(dir) evidence', '(file) clue_pattern.txt', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/key/office/gall...'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/gall...'
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/clue_pattern.txt'}) -> The pattern spells: M I S S I N G _ W I L L _ C H A M B E R
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber/clue_pattern.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/gallery/missing_will_chamber/clue_pattern.txt'
# Calling list_directory({'path': './mazes/hard_maze/key/letter'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/letter'
# Calling check_coordinate({'x': 'office', 'y': 'gallery'}) -> 🎯 Coordinates (office, gallery) are CORRECT! This leads toward the treasure!
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/evidence'}) -> ['(dir) evidence']
# Calling list_directory({'path': './mazes/hard_maze/key/office/gallery/missing_will_chamber'}) -> ['(dir) key']
# Calling check_coordinate({'x': 'evidence', 'y': 'missing_will_chamber'}) -> ❌ Coordinates (evidence, missing_will_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/safe'}) -> ['(dir) salon', '(dir) office']
# Calling list_directory({'path': './mazes/hard_maze/safe/salon'}) ->
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling read_file({'path': './mazes/hard_maze/safe/office/diary'}) -> ['❌ Error: Path is a directory']
# Calling list_directory({'path': './mazes/hard_maze/safe/office'}) -> ['(dir) study', '(dir) gallery', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery'}) -> ['(dir) clue', '(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/clue'}) ->
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/clue'}) -> ['❌ Error: Path is a directory']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (diary, missing_will_chamber)
# Calling check_coordinate({'x': 'diary', 'y': 'missing_will_chamber'}) -> ❌ Coordinates (diary, missing_will_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (diary, missing_will_chamber)
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (diary, missing_will_chamber)
# Calling check_coordinate({'x': 'diary', 'y': 'missing_will_chamber'}) -> ❌ Coordinates (diary, missing_will_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/file_placeholder.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/safe/office/gallery/missing_will_chamber/file_placeholder.txt'
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/'}) -> ['(dir) clue', '(dir) safe', '(dir) missing_will_chamber']
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/study'}) -> ['(dir) office', '(dir) letter', '(file) misleading_clue_2.txt', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/study/misleading_clue_2.txt'}) -> This treasure is just an illusion.
# Calling list_directory({'path': './mazes/hard_maze/'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/hard_maze/safe/office/diary'}) -> ['(dir) clue', '(dir) office', '(dir) missing_will_chamber', "(file) fool's_gold.txt"]
# Calling read_file({'path': "./mazes/hard_maze/safe/office/diary/fool's_gold.txt"}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/safe/office/diary'}) -> ['(dir) clue', '(dir) office', '(dir) missing_will_chamber', "(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/key/letter'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/letter'
# Calling list_directory({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/painting'}) ->
# Calling read_file({'path': './mazes/hard_maze/safe/office/gallery/missing_will_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (diary, missing_will_chamber)
# Calling read_file({'path': './mazes/hard_maze/key/office/gallery/clue_coordinates.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/office/gallery/clue_coordinates.txt'
# Calling list_directory({'path': './mazes/hard_maze/vault'}) -> ['(dir) study', '(dir) evidence', '(dir) office', '(dir) letter', '(file) clue_riddle.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/clue_riddle.txt'}) -> Three letters start my name, OFF. Find where I remain.
# Calling list_directory({'path': './mazes/hard_maze'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling read_file({'path': './mazes/hard_maze/welcome.txt'}) -> Welcome, brave explorer! The HIDDEN_TRUTH awaits those clever enough to solve the ancient puzzles.
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/document'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/document'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/document'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/document'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office'}) -> ['(dir) clue', '(dir) study', '(dir) gallery', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/document'}) ->
# Calling read_file({'path': './mazes/hard_maze/vault/office/clue/document/notes.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/clue/document/notes.txt'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue'}) -> ['(dir) document', '(dir) missing_will_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/clue/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/'}) -> ['(dir) safe', '(dir) study', '(file) rules.txt', '(dir) key', '(file) welcome.txt', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/clue_coordinates.txt'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/vault/office/key/missing_will_chamber/clue_coordinates.txt'
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling read_file({'path': "./mazes/hard_maze/vault/office/key/missing_will_chamber/clue 'logic.txt'"}) -> [Errno 2] No such file or directory: "./mazes/hard_maze/vault/office/key/missing_will_chamber/clue 'logic.txt'"
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/clue_logic.txt'}) -> The path of exclusion leads to MISSING_WILL_CHAMBER
# Calling check_coordinate({'x': 'missing_will_chamber', 'y': 'clue_logic.txt'}) -> ❌ Coordinates (missing_will_chamber, clue_logic.txt) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/clue_logic.txt'}) -> The path of exclusion leads to MISSING_WILL_CHAMBER
# Calling check_coordinate({'x': 'safe', 'y': 'painting'}) -> ❌ Coordinates (safe, painting) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key'}) -> ['(dir) gallery', '(dir) letter', '(dir) missing_will_chamber']
# Calling check_coordinate({'x': 'gallery', 'y': 'missing_will_chamber'}) -> 🎯 Coordinates (gallery, missing_will_chamber) are CORRECT! This leads toward the treasure!
# Calling list_directory({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber'}) -> ['(dir) safe', '(dir) key', '(dir) painting', '(file) clue_logic.txt']
# Calling read_file({'path': './mazes/hard_maze/vault/office/key/missing_will_chamber/clue_logic.txt'}) -> The path of exclusion leads to MISSING_WILL_CHAMBER
# Calling check_coordinate({'x': 'safe', 'y': 'painting'}) -> ❌ Coordinates (safe, painting) do not lead to treasure. Keep searching!
# Found treasure! hidden_truth
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! hidden_truth
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# Found treasure! missing_will
# {'gpt-5-2025-08-07': {'./mazes/easy_maze': {'tool_calls': 22, 'time_spent': 39.64570903778076, 'success': True}, './mazes/medium_maze': {'tool_calls': 10, 'time_spent': 27.50996994972229, 'success': True}, './mazes/hard_maze': {'tool_calls': 163, 'time_spent': 564.232006072998, 'success': False}}, 'gpt-5-mini-2025-08-07': {'./mazes/easy_maze': {'tool_calls': 12, 'time_spent': 18.06856393814087, 'success': True}, './mazes/medium_maze': {'tool_calls': 11, 'time_spent': 21.277427911758423, 'success': True}, './mazes/hard_maze': {'tool_calls': 99, 'time_spent': 265.38145089149475, 'success': False}}, 'gpt-5-nano-2025-08-07': {'./mazes/easy_maze': {'tool_calls': 26, 'time_spent': 45.671645164489746, 'success': True}, './mazes/medium_maze': {'tool_calls': 93, 'time_spent': 223.6497449874878, 'success': True}, './mazes/hard_maze': {'tool_calls': 106, 'time_spent': 208.16770720481873, 'success': True}}}

# %% [markdown]
# ## Results
#
# Let's cover and compare the results of the different LLMs and models.

# %%
for llm_name in test_results:
    print("=" * 70)
    print(f"Results for {llm_name}:")
    for maze_path in test_results[llm_name]:
        print(f"Maze path: {maze_path}")
        print(f"Tool calls: {test_results[llm_name][maze_path]['tool_calls']}")
        print(f"Time spent: {test_results[llm_name][maze_path]['time_spent']}")
        print(f"Success: {test_results[llm_name][maze_path]['success']}")
        print("-" * 70)
    print("\n\n")
# Out:
# ======================================================================
# Results for gpt-5-2025-08-07:
# Maze path: ./mazes/easy_maze
# Tool calls: 22
# Time spent: 39.64570903778076
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/medium_maze
# Tool calls: 10
# Time spent: 27.50996994972229
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/hard_maze
# Tool calls: 163
# Time spent: 564.232006072998
# Success: False
# ----------------------------------------------------------------------
#
#
#
# ======================================================================
# Results for gpt-5-mini-2025-08-07:
# Maze path: ./mazes/easy_maze
# Tool calls: 12
# Time spent: 18.06856393814087
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/medium_maze
# Tool calls: 11
# Time spent: 21.277427911758423
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/hard_maze
# Tool calls: 99
# Time spent: 265.38145089149475
# Success: False
# ----------------------------------------------------------------------
#
#
#
# ======================================================================
# Results for gpt-5-nano-2025-08-07:
# Maze path: ./mazes/easy_maze
# Tool calls: 26
# Time spent: 45.671645164489746
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/medium_maze
# Tool calls: 93
# Time spent: 223.6497449874878
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/hard_maze
# Tool calls: 106
# Time spent: 208.16770720481873
# Success: True
# ----------------------------------------------------------------------
