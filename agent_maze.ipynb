# %% [markdown]
# # Agent Maze Test
#
# In this notebook, we will use a procedural maze generator to create a maze and then use an agent to navigate the maze.
#
# Using this, we can test the performance of an agent navigating the maze, and compare various LLM models tracking
# - time spent
# - number of tool calls
# - if they ever find the treasure (we will set some maximum number of steps to avoid infinite loops)

# %%
# %pip install llama-index-llms-openai

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-..."

# %% [markdown]
# ## Maze Generation
#
# We've vibe-coded a procedural maze generator in `procedural_maze_generator.py`. Hopefully it generates a valid maze! (It does)
#
# Let's start by generating three mazes with different difficulties.

# %%
import os
import shutil
from procedural_maze_generator import ProceduralMazeGenerator, MazeConfig, DifficultyLevel

maze_configs = [
    MazeConfig(
        depth=2,
        difficulty=DifficultyLevel.EASY,
        theme="fantasy",
    ),
    MazeConfig(
        depth=3,
        difficulty=DifficultyLevel.MEDIUM,
        theme="sci-fi",
    ),
    MazeConfig(
        depth=5,
        difficulty=DifficultyLevel.HARD,
        theme="mystery",
        enable_math=True,
        enable_coordinates=True,
        enable_riddles=True,
    )
]

maze_paths = [
    f"./mazes/easy_maze",
    f"./mazes/medium_maze",
    f"./mazes/hard_maze",
]

# Clear out the mazes directory
if os.path.exists("./mazes"):
    shutil.rmtree("./mazes")
    os.makedirs("./mazes", exist_ok=True)

# Generate the mazes
generators = [ProceduralMazeGenerator(maze_config) for maze_config in maze_configs]
for i, maze_path in enumerate(maze_paths):
    generators[i].generate_maze(maze_path)

    stats = generators[i].get_maze_stats()
    print(f"Stats: {stats['total_nodes']} nodes, {stats['total_files']} files")
    print(f"Solution: {' → '.join(stats['solution_path'])}")
    print('-' * 50)
# Out:
# 🎲 Generating procedural maze (depth=2, theme=fantasy)
# ✅ Generated maze with 5 nodes
# 🎯 Treasure path: entrance → golden_idol_chamber
# Stats: 5 nodes, 3 files
# Solution: entrance → golden_idol_chamber
# --------------------------------------------------
# 🎲 Generating procedural maze (depth=3, theme=sci-fi)
# ✅ Generated maze with 14 nodes
# 🎯 Treasure path: entrance → bridge → quantum_core_chamber
# Stats: 14 nodes, 6 files
# Solution: entrance → bridge → quantum_core_chamber
# --------------------------------------------------
# 🎲 Generating procedural maze (depth=5, theme=mystery)
# ✅ Generated maze with 254 nodes
# 🎯 Treasure path: entrance → library → study → basement → hidden_truth_chamber
# Stats: 254 nodes, 92 files
# Solution: entrance → library → study → basement → hidden_truth_chamber
# --------------------------------------------------

# %% [markdown]
# ## Constructing our Agent
#
# To navigate the maze, we will provide the agent with a set of simple tools and instructions.
#
# Obviously, some tools could find the solution instantly, but we want to test the performance of an agent navigating the maze, so we will limit how useful the tools are.

# %% [markdown]
# ### Tools
#
# First, we can construct a simple toolkit for the agent to use. This will contain the tools that the agent can use to navigate the maze and solve the puzzles.

# %%
import asyncio
import os

class AgentMazeToolkit:

    def __init__(self, generator: ProceduralMazeGenerator, maze_path: str):
        self.current_generator = generator
        self.maze_path = maze_path


    async def list_directory(self, path: str) -> list[str]:
        """List the contents of a directory."""
        # Check if the path is within the maze directory
        if not path.startswith(self.maze_path):
            return ["❌ Error: Path is outside of maze directory"]
        
        # Check if the path is a file
        if os.path.isfile(path):
            return ["❌ Error: Path is a file"]
        
        def _list_directory():
            paths = os.listdir(path)

            # Add markers to distinguish between directories and files
            for idx, p in enumerate(paths):
                if os.path.isdir(os.path.join(path, p)):
                    paths[idx] = "(dir) " + p
                else:
                    paths[idx] = "(file) " + p
                    
            return paths
        
        return await asyncio.to_thread(_list_directory)

    async def read_file(self, path: str) -> str:
        """Read the contents of a file."""
        # Check if the path is within the maze directory
        if not path.startswith(self.maze_path):
            return ["❌ Error: Path is outside of maze directory"]
        
        # Check if the path is a directory
        if os.path.isdir(path):
            return ["❌ Error: Path is a directory"]
        
        def _read():
            with open(path, "r") as f:
                return f.read()
            
        return await asyncio.to_thread(_read)

    async def check_coordinate(self, x: str, y: str) -> str:
        """Check if coordinates lead to the treasure location."""
     
        # Get the actual solution path from the generator
        solution_path = self.current_generator.get_solution_path()
        target_path = f"{x}/{y}"
        
        # Check if this matches any part of the solution
        solution_parts = "/".join(solution_path[1:])  # Skip entrance
        if target_path in solution_parts or (x in solution_parts and y in solution_parts):
            result = f"🎯 Coordinates ({x}, {y}) are CORRECT! This leads toward the treasure!"
        else:
            result = f"❌ Coordinates ({x}, {y}) do not lead to treasure. Keep searching!"
        
        return result

# %% [markdown]
# ### Prompts
#
# We need to give a prompt to the agent for both
# - the system prompt
# - the initial task prompt
#
# The hope is that the agent will run the task and won't stop until it has found the treasure.

# %%
def get_system_prompt(maze_path: str, theme: str, difficulty: str, depth: int) -> str:
    return f"""You are competing in a procedural maze tournament!

This is a {difficulty} difficulty {theme} themed maze with {depth} levels.

The maze is represented as a directory structure starting at {maze_path}.

Your goal: Find the treasure hidden in this randomly generated maze.

Available tools:
- list_directory(path): Explore directories  
- read_file(file_path): Read file contents for clues
- check_coordinate(x, y): Test coordinate combinations  

Strategy for {theme} theme:
- Look for {theme}-themed location names and objects
- Clues will reference the theme's vocabulary
- The treasure will have a {theme}-appropriate name

Show your systematic reasoning skills! Remember, the maze path starts at {maze_path}.
"""

def get_task_prompt(maze_path: str, theme: str, difficulty: str) -> str:
    return f"""Navigate this procedural {theme} maze at {maze_path} to find the hidden treasure!

This maze was randomly generated with {difficulty} difficulty. Use your tools strategically to:
1. Explore the maze structure systematically
2. Read files for clues and puzzle solutions
3. Decode any encrypted messages you find
4. Follow logical progression of clues to the treasure

The maze contains both helpful clues and red herrings."""

# %% [markdown]
# ## Testing the Agents
#
# Using everything we have so far, we can test the agents on the mazes.
#
# We will use the following metrics for each LLM/Maze combination:
# - Tool calls
# - Time spent
# - Success
#
# Using the `FunctionAgent` class from `llama_index`, we can create an agent that can use the tools we have defined.
#
# As the agent runs, we can track the events from the stream to keep track of the tool calls and time spent.
#
# Once the agent finishes, we have an automated check to see if the agent actually finished or bailed early.

# %%
import time
from llama_index.core.agent import FunctionAgent, ToolCallResult
from llama_index.core.workflow import Context
from llama_index.llms.openai import OpenAI

llms_to_test = ["gpt-4.1"]
test_results = {llm_name: {} for llm_name in llms_to_test}

for llm_name in llms_to_test:
    for (maze_path, generator) in zip(maze_paths, generators):
        print("=" * 70)
        print(f"Testing {llm_name} on {maze_path}")
        print("=" * 70)
        
        llm = OpenAI(model=llm_name)
        kit = AgentMazeToolkit(generator, maze_path)
        test_results[llm_name][maze_path] = {
            "tool_calls": 0,
            "time_spent": 0,
            "success": False,
        }

        agent = FunctionAgent(
            llm=llm,
            tools=[
                kit.list_directory,
                kit.read_file,
                kit.check_coordinate,
            ],
            system_prompt=get_system_prompt(maze_path, generator.config.theme, generator.config.difficulty.value, generator.config.depth)
        )
        ctx = Context(agent)

        task = get_task_prompt(maze_path, generator.config.theme, generator.config.difficulty.value)
        
        is_done = False
        while not is_done:
            start_time = time.time()

            try:
                handler = agent.run(task, ctx=ctx, max_iterations=100)
                async for event in handler.stream_events():
                    if isinstance(event, ToolCallResult):
                        test_results[llm_name][maze_path]["tool_calls"] += 1
                        print(f"Calling {event.tool_name}({event.tool_kwargs}) -> {event.tool_output}")
                
                response = await handler
                print(f"Response: {response}")
            except Exception as e:
                if "Max iterations" in str(e):
                    print("Max iterations reached! Agent has failed! Halting search to avoid infinite loops...")
                    break
                else:
                    raise e

            # Confirm if actually done
            check_prompt = "Just to confirm, are you done? You found the treasure, right? Respond with 'yes' or 'no' only."
            response = await agent.run(check_prompt, ctx=ctx)
            if "yes" in str(response).lower():
                is_done = True
            else:
                print("Not done yet, continuing...")

        test_results[llm_name][maze_path]["time_spent"] = time.time() - start_time
        test_results[llm_name][maze_path]["success"] = is_done

print(test_results)
# Out:
# ======================================================================
# Testing gpt-4.1 on ./mazes/easy_maze
# ======================================================================
# Calling list_directory({'path': './mazes/easy_maze'}) -> ['(file) rules.txt', '(dir) golden_idol_chamber', '(file) welcome.txt', '(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/cavern'}) -> ['(dir) cavern']
# Calling list_directory({'path': './mazes/easy_maze/golden_idol_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) statue']
# Calling read_file({'path': './mazes/easy_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling read_file({'path': './mazes/easy_maze/welcome.txt'}) -> Welcome, brave explorer! The ANCIENT_TOME awaits those clever enough to solve the ancient puzzles.
# Calling list_directory({'path': './mazes/easy_maze/golden_idol_chamber/statue'}) ->
# Calling list_directory({'path': './mazes/easy_maze/cavern/cavern'}) ->
# Calling read_file({'path': './mazes/easy_maze/golden_idol_chamber/GOLDEN_IDOL.txt'}) -> 🏆 CONGRATULATIONS! You found the GOLDEN_IDOL! 🏆
#
# The legendary treasure has been claimed by a worthy explorer.
# This golden idol grants great power to its finder.
#
# You have successfully navigated the procedural maze and proven your intelligence!
#
# Maze Statistics:
# - Depth: 2 levels
# - Theme: fantasy
# - Difficulty: easy
# - Branching Factor: 3
#
# Response: You have found the treasure!
#
# - The treasure is the GOLDEN_IDOL, located in ./mazes/easy_maze/golden_idol_chamber/GOLDEN_IDOL.txt.
# - The file confirms: "CONGRATULATIONS! You found the GOLDEN_IDOL! The legendary treasure has been claimed by a worthy explorer."
#
# You have successfully navigated the maze and found the fantasy-themed treasure on the first branch. There were no further clues or puzzles needed, as the treasure was directly accessible.
#
# Mission accomplished! If you want to explore the rest of the maze or look for the ANCIENT_TOME mentioned in the welcome message, let me know!
# ======================================================================
# Testing gpt-4.1 on ./mazes/medium_maze
# ======================================================================
# Calling list_directory({'path': './mazes/medium_maze'}) -> ['(dir) bridge', '(file) rules.txt', '(file) welcome.txt', '(dir) engine']
# Calling list_directory({'path': './mazes/medium_maze/engine'}) -> ['(dir) quantum_core_chamber', '(dir) beacon']
# Calling list_directory({'path': './mazes/medium_maze/bridge'}) -> ['(dir) module', '(dir) quantum_core_chamber', '(file) clue_riddle.txt']
# Calling read_file({'path': './mazes/medium_maze/welcome.txt'}) -> Welcome, brave explorer! The NEURAL_MATRIX awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/medium_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/medium_maze/bridge/quantum_core_chamber'}) -> ['(dir) module', '(file) clue_riddle.txt', '(dir) scanner', '(dir) engine']
# Calling list_directory({'path': './mazes/medium_maze/bridge/module'}) -> ['(dir) core', '(dir) drive']
# Calling list_directory({'path': './mazes/medium_maze/engine/quantum_core_chamber'}) -> ['(file) GOLDEN_IDOL.txt', '(dir) bay', '(dir) chamber']
# Calling list_directory({'path': './mazes/medium_maze/engine/beacon'}) ->
# Calling read_file({'path': './mazes/medium_maze/bridge/clue_riddle.txt'}) -> I am not shallow but ___. I am not new but ___. Seek the quantum_core_chamber.
# Calling list_directory({'path': './mazes/medium_maze/engine/quantum_core_chamber/bay'}) ->
# Calling list_directory({'path': './mazes/medium_maze/engine/quantum_core_chamber/chamber'}) -> ['(file) broken_relic.txt']
# Calling list_directory({'path': './mazes/medium_maze/bridge/quantum_core_chamber/module'}) ->
# Calling read_file({'path': './mazes/medium_maze/engine/quantum_core_chamber/GOLDEN_IDOL.txt'}) -> 🏆 CONGRATULATIONS! You found the FUSION_CELL! 🏆
#
# The legendary treasure has been claimed by a worthy explorer.
# This fusion cell grants great power to its finder.
#
# You have successfully navigated the procedural maze and proven your intelligence!
#
# Maze Statistics:
# - Depth: 3 levels
# - Theme: sci-fi
# - Difficulty: medium
# - Branching Factor: 3
#
# Calling read_file({'path': './mazes/medium_maze/bridge/quantum_core_chamber/clue_riddle.txt'}) -> Neither high nor low, but where quantum_core_chamber grows.
# Response: You have successfully navigated the maze!
#
# Summary of the path and clues:
# - The maze started at ./mazes/medium_maze.
# - Clues in the files pointed toward the "quantum_core_chamber."
# - Exploring the engine/quantum_core_chamber directory, I found GOLDEN_IDOL.txt, which revealed the treasure.
#
# Treasure found:
# - The FUSION_CELL, described as a legendary sci-fi treasure granting great power.
#
# You have solved the maze and claimed the FUSION_CELL! If you'd like to see the full path or explore more clues, let me know.
# ======================================================================
# Testing gpt-4.1 on ./mazes/hard_maze
# ======================================================================
# Calling list_directory({'path': './mazes/hard_maze'}) -> ['(dir) evidence', '(file) rules.txt', '(dir) library', '(dir) key', '(file) welcome.txt', '(dir) diary']
# Calling read_file({'file_path': './mazes/hard_maze/welcome.txt'}) -> AgentMazeToolkit.read_file() got an unexpected keyword argument 'file_path'
# Calling read_file({'file_path': './mazes/hard_maze/rules.txt'}) -> AgentMazeToolkit.read_file() got an unexpected keyword argument 'file_path'
# Calling list_directory({'path': './mazes/hard_maze/library'}) -> ['(dir) study', '(dir) evidence', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/key'}) -> ['(dir) study', '(dir) basement']
# Calling list_directory({'path': './mazes/hard_maze/evidence'}) -> ['(dir) study', '(dir) evidence', '(dir) gallery', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/diary'}) -> ['(dir) clue', '(dir) study', '(file) broken_relic.txt']
# Calling read_file({'path': './mazes/hard_maze/welcome.txt'}) -> Welcome, brave explorer! The STOLEN_PAINTING awaits those clever enough to solve the ancient puzzles.
# Calling read_file({'path': './mazes/hard_maze/rules.txt'}) -> Use your tools wisely. Beware of false paths and red herrings!
# Calling list_directory({'path': './mazes/hard_maze/evidence/study'}) -> ['(dir) clue', '(dir) basement', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery'}) -> ['(dir) safe', '(dir) salon', '(dir) basement', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence'}) -> ['(dir) office', '(dir) basement', '(file) misleading_clue_7.txt', '(dir) diary', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/evidence/attic'}) -> ['(dir) clue', '(dir) basement', '(dir) gallery', '(dir) library']
# Calling list_directory({'path': './mazes/hard_maze/library/study'}) -> ['(dir) clue', '(dir) safe', '(dir) basement', '(dir) gallery']
# Calling list_directory({'path': './mazes/hard_maze/key/study'}) -> ['(dir) clue', '(dir) study', '(dir) basement', '(dir) letter', '(file) clue_logic.txt']
# Calling list_directory({'path': './mazes/hard_maze/library/evidence'}) -> ['(file) misleading_clue_8.txt', '(dir) basement', '(dir) library', '(dir) key']
# Calling list_directory({'path': './mazes/hard_maze/diary/clue'}) -> ['(dir) basement', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/key/basement'}) -> ['(dir) basement', '(dir) document', '(dir) attic', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/diary/study'}) -> ['(dir) basement', '(dir) painting']
# Calling read_file({'path': './mazes/hard_maze/library/clue_riddle.txt'}) -> Neither high nor low, but where study grows.
# Calling list_directory({'path': './mazes/hard_maze/library/study/clue'}) -> ['(file) misleading_clue_9.txt']
# Calling read_file({'path': './mazes/hard_maze/library/study/clue/misleading_clue_9.txt'}) -> You're going in circles. Turn back.
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue'}) -> ['(dir) office', '(dir) hidden_truth_chamber', '(dir) letter']
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) safe', '(dir) study', '(dir) basement']
# Calling read_file({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/clue_coordinates.txt'}) -> Ancient map shows location at (letter, hidden_truth_chamber)
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/letter'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/study/clue/hidden_truth_chamber/letter'
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/letter'}) -> ['(dir) clue', '(dir) key', '(dir) document']
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/letter/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/letter/key'}) -> ['(file) misleading_clue_6.txt']
# Calling read_file({'path': './mazes/hard_maze/key/study/clue/letter/key/misleading_clue_6.txt'}) -> A dead end disguised as progress.
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/letter/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/safe'}) -> ['(file) misleading_clue_3.txt']
# Calling read_file({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/safe/misleading_clue_3.txt'}) -> The real prize lies elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/study'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/basement'}) -> ['(file) misleading_clue_4.txt']
# Calling read_file({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/basement/misleading_clue_4.txt'}) -> A dead end disguised as progress.
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting'}) -> ['(dir) safe', '(dir) hidden_truth_chamber', '(dir) library', '(dir) document']
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/hidden_truth_chamber'}) -> ['(dir) clue', '(dir) letter', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/hidden_truth_chamber/letter'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/hidden_truth_chamber/painting'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/hidden_truth_chamber/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/hidden_truth_chamber'}) -> ['(dir) clue', '(dir) letter', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/hidden_truth_chamber/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/library'}) -> ['(dir) office', '(file) misleading_clue_9.txt', '(dir) document']
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/library/office'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/library/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/clue/painting/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting'}) -> ['(dir) safe', '(dir) salon', '(dir) hidden_truth_chamber', '(dir) document']
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting/hidden_truth_chamber'}) -> ['(dir) study']
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting/hidden_truth_chamber/study'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting/salon'}) -> ['(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting/salon/diary'}) ->
# Calling list_directory({'path': './mazes/hard_maze/diary/study/painting/document'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/safe'}) -> ["(file) fool's_gold.txt"]
# Calling read_file({'path': "./mazes/hard_maze/evidence/gallery/safe/fool's_gold.txt"}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic'}) -> ['(dir) hidden_truth_chamber', '(dir) painting']
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic/hidden_truth_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) gallery', '(dir) letter', '(dir) library']
# Calling read_file({'path': './mazes/hard_maze/evidence/gallery/attic/hidden_truth_chamber/clue_coordinates.txt'}) -> The coordinates are marked: X=salon, Y=hidden_truth_chamber
# Calling check_coordinate({'x': 'salon', 'y': 'hidden_truth_chamber'}) -> ❌ Coordinates (salon, hidden_truth_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic/hidden_truth_chamber/gallery'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic/hidden_truth_chamber/letter'}) -> ['(file) misleading_clue_9.txt', "(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic/hidden_truth_chamber/library'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic/painting'}) -> ['(file) broken_relic.txt', '(file) misleading_clue_4.txt', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/evidence/gallery/attic/painting/vault'}) -> ['(file) misleading_clue_4.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/vault'}) -> ['(dir) hidden_truth_chamber', '(dir) gallery', '(dir) key', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/vault/hidden_truth_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) basement']
# Calling read_file({'path': './mazes/hard_maze/evidence/evidence/vault/hidden_truth_chamber/clue_coordinates.txt'}) -> Treasure lies where office meets hidden_truth_chamber
# Calling check_coordinate({'x': 'office', 'y': 'hidden_truth_chamber'}) -> ❌ Coordinates (office, hidden_truth_chamber) do not lead to treasure. Keep searching!
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/vault/hidden_truth_chamber/basement'}) -> ["(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/vault/gallery'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/vault/key'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/vault/vault'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary'}) -> ['(dir) hidden_truth_chamber', '(dir) library', '(dir) document', '(dir) attic']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/hidden_truth_chamber'}) -> ['(dir) clue', '(dir) gallery', '(dir) diary']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/hidden_truth_chamber/diary'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/hidden_truth_chamber/clue'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/hidden_truth_chamber/gallery'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/library'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/document'}) -> ['(file) false_idol.txt', '(file) misleading_clue_1.txt']
# Calling read_file({'path': './mazes/hard_maze/evidence/evidence/diary/document/false_idol.txt'}) -> ❌ This is not the real treasure! Keep searching elsewhere.
# Calling read_file({'path': './mazes/hard_maze/evidence/evidence/diary/document/misleading_clue_1.txt'}) -> This treasure is just an illusion.
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/diary/attic'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/office'}) -> ['(dir) salon', '(dir) hidden_truth_chamber', '(dir) gallery', '(dir) vault']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/office/hidden_truth_chamber'}) -> ['(dir) safe']
# Calling list_directory({'path': './mazes/hard_maze/evidence/evidence/office/hidden_truth_chamber/safe'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue'}) -> ['(dir) safe', '(dir) study', '(dir) hidden_truth_chamber', '(dir) key', "(file) fool's_gold.txt"]
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling read_file({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/clue_riddle.txt'}) -> Three letters start my name, HID. Find where I remain.
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/salon'}) -> ['(file) misleading_clue_8.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/painting'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/painting'}) ->
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/salon'}) -> ['(file) misleading_clue_8.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/study'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/study'
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling check_coordinate({'x': 'painting', 'y': 'hidden_truth_chamber'}) -> ❌ Coordinates (painting, hidden_truth_chamber) do not lead to treasure. Keep searching!
# Calling check_coordinate({'x': 'hidden_truth_chamber', 'y': 'painting'}) -> ❌ Coordinates (hidden_truth_chamber, painting) do not lead to treasure. Keep searching!
# Calling check_coordinate({'x': 'study', 'y': 'hidden_truth_chamber'}) -> 🎯 Coordinates (study, hidden_truth_chamber) are CORRECT! This leads toward the treasure!
# Calling list_directory({'path': './mazes/hard_maze/study/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/study/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/key/study/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/key/study/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/library/study/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/library/study/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/evidence/study/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/diary/study/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/diary/study/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber'}) -> ['(dir) salon', '(dir) painting', '(file) clue_riddle.txt']
# Calling list_directory({'path': './mazes/hard_maze/library/study/clue/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/library/study/clue/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/diary/study/clue/hidden_truth_chamber'}) -> [Errno 2] No such file or directory: './mazes/hard_maze/diary/study/clue/hidden_truth_chamber'
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber'}) -> ['(file) clue_coordinates.txt', '(dir) safe', '(dir) study', '(dir) basement']
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/study'}) ->
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/safe'}) -> ['(file) misleading_clue_3.txt']
# Calling list_directory({'path': './mazes/hard_maze/key/study/clue/hidden_truth_chamber/basement'}) -> ['(file) misleading_clue_4.txt']
# Calling list_directory({'path': './mazes/hard_maze/evidence/study/clue/hidden_truth_chamber/salon'}) -> ['(file) misleading_clue_8.txt']
# Max iterations reached! Agent has failed! Halting search to avoid infinite loops...
# {'gpt-4.1': {'./mazes/easy_maze': {'tool_calls': 8, 'time_spent': 7.669288873672485, 'success': True}, './mazes/medium_maze': {'tool_calls': 15, 'time_spent': 9.71699833869934, 'success': True}, './mazes/hard_maze': {'tool_calls': 120, 'time_spent': 123.54629302024841, 'success': False}}}

# %% [markdown]
# ## Results
#
# Let's cover and compare the results of the different LLMs and models.

# %%
for llm_name in test_results:
    print(f"Results for {llm_name}:")
    for maze_path in test_results[llm_name]:
        print(f"Maze path: {maze_path}")
        print(f"Tool calls: {test_results[llm_name][maze_path]['tool_calls']}")
        print(f"Time spent: {test_results[llm_name][maze_path]['time_spent']}")
        print(f"Success: {test_results[llm_name][maze_path]['success']}")
        print("-" * 70)
# Out:
# Results for gpt-4.1:
# Maze path: ./mazes/easy_maze
# Tool calls: 8
# Time spent: 7.669288873672485
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/medium_maze
# Tool calls: 15
# Time spent: 9.71699833869934
# Success: True
# ----------------------------------------------------------------------
# Maze path: ./mazes/hard_maze
# Tool calls: 120
# Time spent: 123.54629302024841
# Success: False
# ----------------------------------------------------------------------
